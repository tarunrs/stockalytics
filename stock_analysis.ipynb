# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import math
from sklearn.neural_network import MLPClassifier
from sklearn.externals import joblib
import pickle
import os

def get_weekday(date):
    return str(datetime.strptime(date, "%Y-%m-%d").weekday())

# %%
def analyse_ticker(ticker, history=60):
    data = pd.read_csv("raw/" + ticker + ".csv")
    temp = list(data["Close"].copy())
    temp = [0] + temp[:-1]
    data["prev_close"] = temp
    temp1 = list(data["Close"].copy())
    temp1 = [0, 0, 0, 0, 0] + temp1[:-5]
    data["prev_week_close"] = temp1
    data["change"] = data["Close"] - data["prev_close"]
    data["change_week"] = data["Close"] - data["prev_week_close"]
    data["percentage_change"] = data["change"] * 100 / data["Close"]
    data["percentage_change_week"] = data["change_week"] * 100 / data["Close"]
    data = data.drop(data.index[:5])
    data = data.dropna(axis=0, how="any")
    data = data.reset_index(drop=True)
    data["weekday"] = data["Date"].apply(lambda x: get_weekday(x))
    data["label"] = data["percentage_change"].apply(lambda x: int(math.floor(x)))
    data["label"] = data["label"].apply(lambda x: 10 if x > 10 else x)
    data["label"] = data["label"].apply(lambda x: -10 if x < -10 else x)
    data["label"] = data["label"].apply(lambda x: str(x + 10))
    data["label_week"] = data["percentage_change_week"].apply(lambda x: int(math.floor(x)))
    data["label_week"] = data["label_week"].apply(lambda x: 10 if x > 10 else x)
    data["label_week"] = data["label_week"].apply(lambda x: -10 if x < -10 else x)
    data["label_week"] = data["label_week"].apply(lambda x: str(x + 10))
    temp2 = list(data["label_week"].copy())
    temp2 = temp2[5:] + [np.nan, np.nan, np.nan, np.nan, np.nan]
    data["label_next_week"] = temp2
    for i in range(history, len(data)):
        for j in range(1, history + 1):
            data.at[i, 'prev_label_' + str(j)] = data.iloc[i - j]['label']
            data.at[i, 'prev_label_week_' + str(j)] = data.iloc[i - j]['label_week']
    data = data.dropna(axis=0, how="any")
    data = data.reset_index(drop=True)
    return data

# %%
def get_train_test(df, num_train, skip_days=0):
    data = df.copy()
    del data["Volume"]
    del data["prev_close"]
    del data["change"]
    del data["percentage_change"]
    del data["Adj Close"]
    del data["Open"]
    del data["High"]
    del data["Low"]
    del data["Close"]
    del data["Date"]
    labels = data["label_next_week"].copy()
    #del data["label"]
    #del data["label_week"]
    del data["label_next_week"]
    if skip_days:
        for i in range(1, skip_days + 1):
            del data["prev_label_" + str(i)]
            del data["prev_label_week_" + str(i)]
    data = pd.get_dummies(data)
    train_data = data[:num_train].copy()
    train_labels = labels[:num_train].copy()
    test_data = data[num_train:].copy()
    test_labels = labels[num_train:].copy()
    return train_data, train_labels, test_data, test_labels

def get_average_prediction(probabilities, classes):
    ret = []
    for p in probabilities:
        indexes = p.argsort()[-3:]
        labels = classes[indexes]
        label = round(np.mean([int(el) for el in labels]))
        ret.append(str(int(label)))
    return ret

def evaluate_confusion_matrix(mat):
    results = []
    totals = []
    correct = 0
    incorrect = 0
    for i in range(21):
        if i > 10:
            correct += sum(mat[i][11:])
            incorrect += sum(mat[i][:11])
        else:
            correct += sum(mat[i][i:])
            incorrect += sum(mat[i][:i])
    total = correct + incorrect
    #print correct, incorrect, total
    return correct / float(total)

def get_model(train_data, train_labels, test_data, test_labels):
    #print len(train_data), len(train_labels), len(test_data), len(test_labels)
    clf = MLPClassifier(alpha=1e-5, hidden_layer_sizes=(200, 100, 100, 100, 100, 200), random_state=1, max_iter=1000)
    clf.fit(train_data, train_labels)
    train_accuracy = clf.score(train_data, train_labels)
    test_accuracy = clf.score(test_data, test_labels)
    #print "Training accuracy(exact):", train_accuracy
    #print "Test accuracy(exact):", test_accuracy
    #print "Loss:", clf.loss_
    return clf, clf.loss_, train_accuracy, test_accuracy

def evaluate_model(clf, test_data, test_labels):
    predicted_labels = clf.predict(test_data)
    cm1 = confusion_matrix(predicted_labels, test_labels, labels=[str(i) for i in range(21)])
    predicted_probabilities = clf.predict_proba(test_data)
    average_labels = get_average_prediction(predicted_probabilities, clf.classes_)
    cm2 = confusion_matrix(average_labels, test_labels, labels=[str(i) for i in range(21)])
    soft_accuracy_exact = evaluate_confusion_matrix(cm1)
    soft_accuracy_avg = evaluate_confusion_matrix(cm2)
    #print "Accuracy exact(soft):", soft_accuracy_exact
    #print "Accuracy average(soft):", soft_accuracy_avg
    return soft_accuracy_exact, soft_accuracy_avg

#print datasets[0][["Date", "Close", "prev_close", "label_next_week", "label_week"]]

# %%
#tickers = ["INFY", "SBIN", "APOLLOTYRE", "LUMAXTECH", "JUBLFOOD", "PRAKASH"]
tickers = os.listdir("raw")
for symbol in tickers:
    results = pickle.load(open("results.pkl"))
    try:
        symbol = symbol.split(".")[0]
        if os.path.isfile("models/" + symbol + ".pkl"): 
            print "Skipping:", symbol
            continue
        dataset = analyse_ticker(symbol)
        pickle.dump(dataset, open("data/" + symbol + ".pkl", "wb"))
        train_split_index = len(dataset) - 20
        train_data, train_labels, test_data, test_labels = get_train_test(dataset, train_split_index)
        pickle.dump(train_data, open("train/" + symbol + "_data.pkl", "wb"))
        pickle.dump(train_labels, open("train/" + symbol + "_labels.pkl", "wb"))
        pickle.dump(test_data, open("test/" + symbol + "_data.pkl", "wb"))
        pickle.dump(test_labels, open("test/" + symbol + "_labels.pkl", "wb"))
        clf, loss, train_accuracy, test_accuracy = get_model(train_data, train_labels, test_data, test_labels)
        soft_accuracy_exact, soft_accuracy_avg = evaluate_model(clf, test_data, test_labels)
        results[symbol] = dict()
        results[symbol]["loss"] = loss
        results[symbol]["train_accuracy"] = train_accuracy
        results[symbol]["test_accuracy"] = test_accuracy
        results[symbol]["soft_accuracy_exact"] = soft_accuracy_exact
        results[symbol]["soft_accuracy_avg"] = soft_accuracy_avg
        print symbol, soft_accuracy_avg
        joblib.dump(clf, "models/"+ symbol + ".pkl")
    except Exception as e:
        print symbol, str(e)
    pickle.dump(results, open("results.pkl", "wb"))
# Out:
# Skipping: MAHLOG
# Skipping: OISL
# Skipping: GKWLIMITED
# Skipping: NAGREEKCAP
# Skipping: GUFICBIO
# Skipping: LYCOS
# Skipping: AUSOMENT
# Skipping: GESHIP
# Skipping: THEMISMED
# Skipping: DOLPHINOFF
# Skipping: KOTAKBANK
# Skipping: INDIANHUME
# Skipping: ORBTEXP
# Skipping: DTIL
# Skipping: BANKBEES
# Skipping: FMGOETZE
# Skipping: KOTAKGOLD
# Skipping: TVSELECT
# Skipping: ESABINDIA
# Skipping: APLAPOLLO
# Skipping: SABTN
# BOHRA 'Close'
# Skipping: INDOTECH
# Skipping: BHARTIARTL
# Skipping: TIMESGTY
# Skipping: SATIN
# Skipping: OILCOUNTUB
# Skipping: JUBLFOOD
# Skipping: ADHUNIK
# Skipping: JSL
# INFOBEAN 'Close'
# JETKNIT 'Close'
# Skipping: NOIDATOLL
# Skipping: TPLPLASTEH
# Skipping: BALAMINES
# Skipping: SHRIRAMEPC
# Skipping: RSWM
# Skipping: DEEPIND
# Skipping: TVSSRICHAK
# Skipping: VENUSREM
# Skipping: TEXRAIL
# Skipping: DSSL
# Skipping: CENTEXT
# Skipping: VOLTAS
# Skipping: AVADHSUGAR
# Skipping: ADSL
# Skipping: FIEMIND
# Skipping: KAKATCEM
# Skipping: BEML
# Skipping: APCOTEXIND
# Skipping: TATAMTRDVR
# Skipping: SUNTV
# Skipping: CORPBANK
# Skipping: JMA
# Skipping: KARMAENG
# Skipping: TALBROAUTO
# Skipping: TNPETRO
# Skipping: KIRLOSIND
# Skipping: DPSCLTD
# L&TFINANCE 'Close'
# Skipping: AUTOAXLES
# Skipping: TINPLATE
# Skipping: CORDSCABLE
# Skipping: IDBIGOLD
# Skipping: BIOCON
# Skipping: ASTRAL
# Skipping: ROLTA
# SAKAR 'Close'
# HHOF1140RG 'Close'
# Skipping: ELGIRUBCO
# Skipping: LICHSGFIN
# MAHICKRA 'Close'
# EMOFSR1RGG 'Close'
# Skipping: NELCO
# Skipping: SHILPI
# ZOTA 'Close'
# Skipping: MAHLIFE
# Skipping: DEEPAKFERT
# Skipping: DYNPRO
# Skipping: MOIL
# Skipping: UNICHEMLAB
# SGBMAY25 'Close'
# Skipping: KAVVERITEL
# Skipping: AMRUTANJAN
# Skipping: DHUNINV
# Skipping: HPL
# Skipping: ANDHRSUGAR
# Skipping: MAGMA
# Skipping: SHOPERSTOP
# Skipping: ARCHIDPLY
# Skipping: SYNCOM
# Skipping: NATCOPHARM
# Skipping: HUDCO
# NHBTF2014 'Close'
# Skipping: IDFCBANK
# Skipping: PARSVNATH
# Skipping: BHAGYAPROP
# Skipping: MOREPENLAB
# Skipping: SMPL
# Skipping: LTTS
# Skipping: TFCILTD
# Skipping: JINDRILL
# Skipping: SPECIALITY
# MITCON 'Close'
# Skipping: MAJESCO
# Skipping: ASTRAMICRO
# Skipping: ONWARDTEC
# Skipping: GOCLCORP
# Skipping: HILTON
# Skipping: KITEX
# Skipping: MOLDTKPAC
# Skipping: LYKALABS
# Skipping: BANDHANBNK
# Skipping: SHREYANIND
# Skipping: ALKALI
# Skipping: SHREYAS
# Skipping: SUNPHARMA
# Skipping: MORARJEE
# Skipping: SPARC
# NHAI 'Close'
# Skipping: RAJTV
# Skipping: HINDSYNTEX
# Skipping: DREDGECORP
# Skipping: INFY
# Skipping: ZEEL
# Skipping: STRTECH
# Skipping: COX&KINGS
# Skipping: GTL
# Skipping: ASTRON
# Skipping: MEGH
# Skipping: CTE
# Skipping: ISFT
# Skipping: WELINV
# Skipping: JKCEMENT
# Skipping: PANORAMUNI
# Skipping: ISMTLTD
# Skipping: DHARSUGAR
# Skipping: VISESHINFO
# Skipping: AHLEAST
# Skipping: ONGC
# JTEKTINDIA Length of values does not match length of index
# Skipping: PATSPINLTD
# Skipping: SHARIABEES
# Skipping: M&M
# Skipping: SIGNET
# Skipping: TGBHOTELS
# Skipping: BALLARPUR
# Skipping: ASIANPAINT
# Skipping: SAMTEL
# Skipping: ASIANHOTNR
# Skipping: PCJEWELLER
# MAHESHWARI 'Close'
# Skipping: DUCON
# Skipping: RUCHIRA
# Skipping: IFBAGRO
# Skipping: GITANJALI
# Skipping: HINDALCO
# Skipping: HFCL
# Skipping: MUKTAARTS
# EMOFSR1RDP 'Close'
# SGBNOV25IX 'Close'
# Skipping: BBL
# Skipping: CENTURYPLY
# Skipping: VRLLOG
# Skipping: ICICIGI
# Skipping: MARUTI
# Skipping: EXCELINDUS
# ICICINF100 Found array with 0 sample(s) (shape=(0, 9)) while a minimum of 1 is required.
# Skipping: FORTUNEFIN
# Skipping: USHAMART
# Skipping: NACLIND
# Skipping: DNAMEDIA
# Skipping: JSWHL
# Skipping: DCW
# Skipping: TORNTPHARM
# Skipping: DALMIASUG
# Skipping: BANCOINDIA
# Skipping: GMBREW
# SGBAUG24 'Close'
# Skipping: STARCEMENT
# CONTI 'Close'
# Skipping: HINDPETRO
# Skipping: PRICOLLTD
# Skipping: KOTHARIPET
# Skipping: MIC
# Skipping: ELECTCAST
# Skipping: RAMCOCEM
# Skipping: DCBBANK
# ECLFINANCE 'Close'
# Skipping: MINDAIND
# KARDA Found array with 0 sample(s) (shape=(0, 18)) while a minimum of 1 is required.
# Skipping: STEL
# Skipping: OMAXE
# Skipping: ORTEL
# Skipping: OFSS
# Skipping: CMICABLES
# Skipping: EVERESTIND
# 21STCENMGM Found array with 0 sample(s) (shape=(0, 438)) while a minimum of 1 is required.
# Skipping: INOXLEISUR
# Skipping: PERSISTENT
# Skipping: SPIC
# Skipping: DPL
# Skipping: HDFC
# Skipping: ASHIANA
# Skipping: RAMANEWS
# Skipping: RKDL
# Skipping: GRASIM
# Skipping: GALLANTT
# Skipping: CELEBRITY
# Skipping: NSIL
# Skipping: ARENTERP
# Skipping: MANAPPURAM
# Skipping: PUNJABCHEM
# Skipping: PRATIBHA
# AIROLAM 'Close'
# Skipping: SAKHTISUG
# Skipping: MANGCHEFER
# Skipping: SURANAIND
# Skipping: GULPOLY
# Skipping: EXCEL
# Skipping: HDFCLIFE
# Skipping: KALPATPOWR
# Skipping: DABUR
# BSHSL 'Close'
# Skipping: PRIMESECU
# Skipping: GATI
# Skipping: RADIOCITY
# Skipping: CIMMCO
# Skipping: ASTERDM
# Skipping: GILLETTE
# Skipping: JAGRAN
# Skipping: ROHITFERRO
# SGBOCT25IV 'Close'
# Skipping: MANGALAM
# Skipping: HEG
# Skipping: GUJFLUORO
# Skipping: BANG
# Skipping: JITFINFRA
# Skipping: DOLLAR
# Skipping: TAKE
# Skipping: DELTACORP
# Skipping: RAJVIR
# Skipping: ROSSELLIND
# Skipping: SWELECTES
# Skipping: KOKUYOCMLN
# Skipping: KGL
# Skipping: JAMNAAUTO
# Skipping: TATAMETALI
# Skipping: MINDACORP
# Skipping: HARITASEAT
# Skipping: OMKARCHEM
# EIFFL 'Close'
# MAGADSUGAR 'Close'
# Skipping: MONTECARLO
# Skipping: SCAPDVR
# SUREVIN 'Close'
# Skipping: WINSOME
# SILVERTUC 'Close'
# Skipping: SANGHIIND
# Skipping: UTTAMSTL
# Skipping: BANARISUG
# Skipping: IFCI
# Skipping: BHUSANSTL
# SPTL 'Close'
# ONEPOINT 'Close'
# Skipping: KANSAINER
# Skipping: RPOWER
# Skipping: MOLDTECH
# Skipping: WEIZMANIND
# Skipping: ALICON
# Skipping: ARSHIYA
# Skipping: ZEEMEDIA
# Skipping: NESCO
# Skipping: AVTNPL
# BETA 'Close'
# Skipping: COMPINFO
# Skipping: GRAVITA
# Skipping: POWERMECH
# TOUCHWOOD 'Close'
# Skipping: JPPOWER
# Skipping: HITECHGEAR
# Skipping: AARTIDRUGS
# Skipping: GUJAPOLLO
# Skipping: NRAIL
# Skipping: FORTIS
# Skipping: UNIVCABLES
# Skipping: WELENT
# Skipping: HGINFRA
# Skipping: RELNV20
# Skipping: HINDCOMPOS
# 3PLAND 'Close'
# Skipping: UNIONBANK
# Skipping: CRMFGETF
# Skipping: SUPREMETEX
# LICNETFSEN 'Close'
# Skipping: IMPEXFERRO
# Skipping: VIPULLTD
# Skipping: VIMALOIL
# Skipping: SANWARIA
# Skipping: NAHARPOLY
# Skipping: DLF
# Skipping: TRENT
# TIRUPATIFL 'Close'
# Skipping: ASSAMCO
# Skipping: AEGISCHEM
# Skipping: PREMEXPLN
# Skipping: RANASUG
# Skipping: SAREGAMA
# Skipping: BIGBLOC
# Skipping: RAINBOWPAP
# Skipping: PROZONINTU
# Skipping: SARDAEN
# Skipping: MAYURUNIQ
# Skipping: HERCULES
# MKPL 'Close'
# Skipping: PREMIERPOL
# Skipping: WABAG
# ASLIND 'Close'
# Skipping: SHIVATEX
# Skipping: JINDALSAW
# Skipping: KOTHARIPRO
# Skipping: LAURUSLABS
# Skipping: DEEPAKNTR
# Skipping: DMART
# Skipping: JAYAGROGN
# Skipping: PFC
# STAN 'Close'
# Skipping: UNITEDTEA
# Skipping: INDOWIND
# ICICINIFTY Found array with 0 sample(s) (shape=(0, 9)) while a minimum of 1 is required.
# Skipping: MARATHON
# Skipping: JKTYRE
# Skipping: UFO
# Skipping: SELMCL
# Skipping: SREEL
# Skipping: VASWANI
# TARACHAND 'Close'
# SOLEX 'Close'
# Skipping: TECHM
# Skipping: REDINGTON
# Skipping: HANUNG
# Skipping: TECHNO
# Skipping: SAGCEM
# Skipping: MUKANDLTD
# Skipping: CAPLIPOINT
# Skipping: 20MICRONS
# Skipping: HITECHCORP
# Skipping: WANBURY
# Skipping: HARRMALAYA
# Skipping: ARIHANT
# Skipping: SURANASOL
# Skipping: PANACEABIO
# Skipping: BASF
# Skipping: HERITGFOOD
# Skipping: NDL
# Skipping: TCS
# Skipping: CHENNPETRO
# Skipping: RUBYMILLS
# Skipping: MUTHOOTCAP
# Skipping: DAAWAT
# Skipping: ARIES
# Skipping: MRO-TEK
# Skipping: PNBGILTS
# Skipping: NATNLSTEEL
# SGBJUL25 'Close'
# Skipping: HAL
# IIHFL 'Close'
# Skipping: MCX
# Skipping: HINDMOTORS
# Skipping: HMT
# Skipping: RAMASTEEL
# Skipping: BSLIMITED
# Skipping: RALLIS
# Skipping: YESBANK
# Skipping: NCLIND
# Skipping: GODREJIND
# Skipping: PPAP
# Skipping: PETRONENGG
# Skipping: ADVANIHOTR
# Skipping: LOTUSEYE
# Skipping: GICHSGFIN
# Skipping: SIS
# Skipping: GREAVESCOT
# Skipping: WSI
# Skipping: TREEHOUSE
# SGFL Found array with 0 sample(s) (shape=(0, 13)) while a minimum of 1 is required.
# Skipping: NBIFIN
# Skipping: MFSL
# Skipping: JINDCOT
# Skipping: TCIEXP
# Skipping: MANUGRAPH
# CENTRUM Found array with 0 sample(s) (shape=(0, 14)) while a minimum of 1 is required.
# Skipping: VETO
# Skipping: LUPIN
# Skipping: INDHOTEL
# Skipping: BALKRISIND
# Skipping: IGARASHI
# Skipping: SORILHOLD
# Skipping: BKMINDST
# Skipping: HINDZINC
# LEMONTREE Found array with 0 sample(s) (shape=(0, 21)) while a minimum of 1 is required.
# Skipping: CLNINDIA
# Skipping: LUXIND
# Skipping: EMAMIINFRA
# Skipping: PFIZER
# Skipping: SIMPLEXINF
# Skipping: NAVKARCORP
# SIIL 'Close'
# Skipping: DALMIABHA
# Skipping: ITC
# Skipping: IMFA
# Skipping: GOLDINFRA
# Skipping: SUTLEJTEX
# Skipping: AKSHOPTFBR
# Skipping: DIAMONDYD
# Skipping: RUSHIL
# ICICIB22 'Close'
# Skipping: BLUESTARCO
# Skipping: TATAINVEST
# Skipping: LT
# SGBFEB24 'Close'
# Skipping: BHARATGEAR
# Skipping: GRAPHITE
# Skipping: RTNPOWER
# Skipping: ZUARI
# Skipping: VLSFINANCE
# Skipping: KKCL
# Skipping: INVENTURE
# Skipping: SUNCLAYLTD
# Skipping: RENUKA
# Skipping: TEAMLEASE
# Skipping: RADICO
# Skipping: MAITHANALL
# Skipping: FCL
# Skipping: MANPASAND
# Skipping: TECHNOFAB
# APOLLO Found array with 0 sample(s) (shape=(0, 3)) while a minimum of 1 is required.
# Skipping: ADHUNIKIND
# WORTH 'Close'
# Skipping: GEMINI
# Skipping: GPPL
# Skipping: MAANALU
# Skipping: POLYPLEX
# Skipping: SANDESH
# Skipping: FLEXITUFF
# Skipping: SOUTHBANK
# Skipping: WALCHANNAG
# Skipping: PRAJIND
# Skipping: KESORAMIND
# Skipping: AROGRANITE
# Skipping: MENONBE
# Skipping: IEX
# Skipping: JKIL
# Skipping: SELAN
# Skipping: CHOLAFIN
# PENTAGOLD 'Close'
# Skipping: KINGFA
# Skipping: GARDENSILK
# Skipping: ORIENTBELL
# Skipping: CEBBCO
# Skipping: M100
# Skipping: TANLA
# Skipping: JUSTDIAL
# Skipping: PIONEEREMB
# Skipping: TIDEWATER
# Skipping: NRBBEARING
# PALASHSECU 'Close'
# FELIX 'Close'
# Skipping: NITESHEST
# Skipping: SIMPLEX
# Skipping: DBREALTY
# Skipping: ACE
# Skipping: SUNDRMFAST
# Skipping: SYNGENE
# Skipping: EQ30
# Skipping: PIONDIST
# Skipping: MUTHOOTFIN
# VSCL 'Close'
# Skipping: KTIL
# Skipping: MSPL
# Skipping: JAGSNPHARM
# Skipping: RSSOFTWARE
# Skipping: PODDARMENT
# Skipping: TRIL
# Skipping: NAKODA
# Skipping: HDFCMFGETF
# Skipping: ZODIACLOTH
# Skipping: SDBL
# Skipping: INSECTICID
# IRBINVIT 'Close'
# Skipping: INDIANCARD
# Skipping: HOVS
# Skipping: SSWL
# Skipping: ACCELYA
# Skipping: MAHAPEXLTD
# Skipping: VIPCLOTHNG
# Skipping: EMMBI
# Skipping: TVVISION
# Skipping: STEELXIND
# Skipping: GNFC
# Skipping: ESSELPACK
# Skipping: MBECL
# Skipping: METKORE
# Skipping: KALYANIFRG
# Skipping: VASCONEQ
# Skipping: IPCALAB
# Skipping: ARROWGREEN
# Skipping: GTNIND
# Skipping: AUTOLITIND
# Skipping: BSL
# Skipping: KPIT
# Skipping: SEZAL
# Skipping: ASHOKA
# Skipping: PODDARHOUS
# Skipping: PUNJLLOYD
# Skipping: KDDL
# Skipping: BFINVEST
# Skipping: LAOPALA
# Skipping: SEAMECLTD
# Skipping: SREINFRA
# Skipping: DONEAR
# Skipping: SABEVENTS
# Skipping: PRECWIRE
# Skipping: MASFIN
# Skipping: RELDIVOPP
# Skipping: EVEREADY
# Skipping: EUROTEXIND
# Skipping: TRITURBINE
# Skipping: UNIPLY
# Skipping: KMSUGAR
# Skipping: JKPAPER
# Skipping: EMCO
# Skipping: IOLCP
# Skipping: ISEC
# Skipping: XLENERGY
# Skipping: INDOTHAI
# Skipping: POKARNA
# Skipping: ABB
# IIFCL 'Close'
# Skipping: JAICORPLTD
# Skipping: KOTAKPSUBK
# Skipping: AXISCADES
# Skipping: SWARAJENG
# Skipping: VIPIND
# Skipping: PRAKASHCON
# Skipping: ATFL
# Skipping: MGL
# Skipping: GOKULAGRO
# INNOVATIVE 'Close'
# Skipping: BAYERCROP
# Skipping: IL&FSTRANS
# Skipping: GUJGASLTD
# Skipping: BANKBARODA
# Skipping: BAJAJHIND
# Skipping: UCOBANK
# Skipping: CCL
# Skipping: SARLAPOLY
# Skipping: BEARDSELL
# Skipping: TNPL
# Skipping: DELTAMAGNT
# Skipping: MOHITIND
# Skipping: JETAIRWAYS
# Skipping: KAMATHOTEL
# Skipping: TOKYOPLAST
# Skipping: ADORWELD
# Skipping: SUNDARAM
# Skipping: LALPATHLAB
# Skipping: NAGAROIL
# Skipping: BALAJITELE
# Skipping: PINCON
# Skipping: OMMETALS
# Skipping: RANEHOLDIN
# Skipping: OPTIEMUS
# Skipping: KIRLOSBROS
# Skipping: NAVNETEDUL
# Skipping: WENDT
# Skipping: BLUEBLENDS
# Skipping: INDTERRAIN
# Skipping: TANTIACONS
# SGBNOV23 'Close'
# Skipping: RECLTD
# Skipping: PILITA
# Skipping: MADRASFERT
# Skipping: VIVIMEDLAB
# Skipping: SOMICONVEY
# Skipping: FELDVR
# Skipping: RANEENGINE
# Skipping: NAVINFLUOR
# Skipping: KANORICHEM
# Skipping: PAEL
# Skipping: LINCPEN
# Skipping: COSMOFILMS
# KRISHANA 'Close'
# STEELCITY 'Close'
# Skipping: HESTERBIO
# Skipping: GAIL
# Skipping: AXISGOLD
# Skipping: VADILALIND
# Skipping: THOMASCOTT
# Skipping: GALAXYSURF
# Skipping: LAXMIMACH
# Skipping: PHOENIXLTD
# Skipping: HATHWAY
# Skipping: HIGHGROUND
# Skipping: BIOFILCHEM
# Skipping: GEECEE
# ICICIGOLD Found array with 0 sample(s) (shape=(0, 9)) while a minimum of 1 is required.
# UTINEXT50 'Close'
# Skipping: ASHAPURMIN
# Skipping: RNAVAL
# Skipping: CRISIL
# Skipping: MANDHANA
# Skipping: RUCHISOYA
# Skipping: EDELWEISS
# Skipping: LPDC
# Skipping: GDL
# Skipping: TI
# Skipping: GLENMARK
# Skipping: PSL
# Skipping: EKC
# Skipping: ABGSHIP
# Skipping: SRSLTD
# Skipping: ORIENTLTD
# Skipping: TAJGVK
# Skipping: ARSSINFRA
# Skipping: INDIAGLYCO
# Skipping: ZENTEC
# Skipping: SKMEGGPROD
# Skipping: SKIL
# BDL index 1 is out of bounds for axis 1 with size 1
# Skipping: ABCAPITAL
# Skipping: TODAYS
# Skipping: VIMTALABS
# Skipping: SHARDAMOTR
# Skipping: PIDILITIND
# Skipping: GRANULES
# Skipping: CINELINE
# Skipping: MVL
# Skipping: PALREDTEC
# Skipping: NATHBIOGEN
# Skipping: KEC
# Skipping: TERASOFT
# Skipping: TIFIN
# Skipping: GRINDWELL
# Skipping: KWALITY
# Skipping: AHLWEST
# SOUTHWEST 'Close'
# Skipping: BEDMUTHA
# Skipping: CENTUM
# Skipping: WEBELSOLAR
# Skipping: CIGNITITEC
# Skipping: RPGLIFE
# Skipping: INDSWFTLAB
# Skipping: TIIL
# Skipping: UNITY
# Skipping: ASPINWALL
# Skipping: UPL
# Skipping: PDMJEPAPER
# Skipping: AGRITECH
# Skipping: MAWANASUG
# Skipping: MEGASOFT
# Skipping: RELINFRA
# Skipping: CENTENKA
# Skipping: SURANAT&P
# Skipping: GANECOS
# Skipping: SONATSOFTW
# GLOBAL 'Close'
# Skipping: SANGHVIFOR
# Skipping: JCHAC
# Skipping: HEIDELBERG
# Skipping: GREENPOWER
# Skipping: MANAKCOAT
# Skipping: PTL
# Skipping: GOKUL
# Skipping: PNC
# TOTAL 'Close'
# Skipping: VOLTAMP
# Skipping: SAKUMA
# Skipping: INFRABEES
# Skipping: COMPUSOFT
# Skipping: KNRCON
# Skipping: JINDALPHOT
# Skipping: HDFCNIFETF
# NABARD 'Close'
# Skipping: MOTOGENFIN
# Skipping: TATACOFFEE
# Skipping: ASAHISONG
# Skipping: TALWALKARS
# Skipping: COALINDIA
# Skipping: RAMGOPOLY
# Skipping: LOVABLE
# SMVD 'Close'
# Skipping: TIMKEN
# Skipping: GANDHITUBE
# Skipping: TRIGYN
# Skipping: KRBL
# Skipping: DRREDDY
# Skipping: GAL
# Skipping: GINNIFILA
# Skipping: ATUL
# Skipping: KELLTONTEC
# Skipping: TV18BRDCST
# Skipping: IMPAL
# Skipping: EICHERMOT
# Skipping: RELIANCE
# Skipping: CANDC
# Skipping: BEL
# Skipping: INFINITE
# Skipping: IOB
# Skipping: INDRAMEDCO
# Skipping: RELAXO
# SERVOTECH 'Close'
# Skipping: AMJLAND
# Skipping: HONAUT
# AJOONI 'Close'
# Skipping: SHYAMCENT
# Skipping: DCMFINSERV
# KEERTI 'Close'
# Skipping: PRADIP
# Skipping: NECLIFE
# ICICINV20 'Close'
# Skipping: MOHOTAIND
# Skipping: SALSTEEL
# Skipping: JINDALSTEL
# Skipping: COCHINSHIP
# Skipping: GNA
# Skipping: MHRIL
# Skipping: MIRZAINT
# Skipping: GSCLCEMENT
# Skipping: PRECOT
# Skipping: SETCO
# Skipping: GEPIL
# Skipping: ITDCEM
# Skipping: NATIONALUM
# Skipping: LGBBROSLTD
# Skipping: MARKSANS
# Skipping: NAHARINDUS
# Skipping: FEDERALBNK
# BANSAL 'Close'
# Skipping: BALPHARMA
# Skipping: SHARDACROP
# Skipping: THOMASCOOK
# SGBMAR25 'Close'
# CROWN 'Close'
# Skipping: DIAPOWER
# JASH 'Close'
# Skipping: AURIONPRO
# Skipping: CENTRALBK
# Skipping: ORTINLABSS
# Skipping: JAIBALAJI
# Skipping: QUESS
# Skipping: BLKASHYAP
# Skipping: SPYL
# Skipping: RUCHINFRA
# Skipping: RESPONIND
# Skipping: KSCL
# Skipping: ORICONENT
# SSINFRA 'Close'
# Skipping: DCMSHRIRAM
# Skipping: ALKEM
# INDIGRID 'Close'
# Skipping: MINDTECK
# Skipping: AMARAJABAT
# Skipping: APOLLOTYRE
# Skipping: CAMLINFINE
# Skipping: SCHAND
# Skipping: BAJAJELEC
# Skipping: GENESYS
# Skipping: JBFIND
# Skipping: BATAINDIA
# Skipping: GRUH
# Skipping: CGPOWER
# Skipping: SHAHALLOYS
# Skipping: TATAPOWER
# Skipping: CUB
# Skipping: WOCKPHARMA
# SREIBNPNCD 'Close'
# Skipping: KCP
# Skipping: SOBHA
# Skipping: DCM
# Skipping: SUZLON
# Skipping: MTNL
# Skipping: MANGLMCEM
# Skipping: BHARATIDIL
# Skipping: SUNDRMBRAK
# Skipping: JAYSREETEA
# RKEC 'Close'
# Skipping: GET&D
# Skipping: GODREJPROP
# Skipping: VEDL
# Skipping: CYBERTECH
# Skipping: KIRLOSENG
# Skipping: PONNIERODE
# Skipping: INDBANK
# Skipping: VAKRANGEE
# Skipping: EXIDEIND
# Skipping: DQE
# Skipping: PILANIINVS
# Skipping: KIRIINDUS
# Skipping: SUBROS
# Skipping: HSCL
# WEALTH 'Close'
# Skipping: SITASHREE
# Skipping: TARMAT
# Skipping: AFL
# Skipping: FSC
# Skipping: KEI
# Skipping: SATHAISPAT
# JALAN 'Close'
# Skipping: VAIBHAVGBL
# Skipping: SMLISUZU
# Skipping: PFOCUS
# Skipping: VARDMNPOLY
# Skipping: TMRVL
# Skipping: NH
# Skipping: SETFGOLD
# Skipping: DHANBANK
# Skipping: IRB
# Skipping: SHIVAMILLS
# Skipping: ENERGYDEV
# Skipping: ITI
# Skipping: TEJASNET
# Skipping: HGS
# Skipping: AMBUJACEM
# Skipping: RPPINFRA
# Skipping: STERTOOLS
# Skipping: GLOBALVECT
# Skipping: BYKE
# Skipping: MAHSCOOTER
# Skipping: ZEELEARN
# Skipping: PTC
# Skipping: VIJIFIN
# Skipping: ALPHAGEO
# Skipping: SRTRANSFIN
# Skipping: NAGAFERT
# Skipping: GLOBOFFS
# Skipping: AGCNET
# Skipping: CREST
# Skipping: PGEL
# Skipping: ENGINERSIN
# Skipping: SICAGEN
# Skipping: RRSLGETF
# Skipping: SHRIPISTON
# Skipping: ATULAUTO
# Skipping: POLYMED
# Skipping: ALBERTDAVD
# Skipping: STINDIA
# Skipping: IFGLEXPOR
# Skipping: MONNETISPA
# Skipping: SIMBHALS
# Skipping: JPINFRATEC
# Skipping: CAPF
# Skipping: VISAKAIND
# Skipping: KICL
# Skipping: CHROMATIC
# Skipping: ASTEC
# Skipping: EASTSILK
# Skipping: KAYA
# Skipping: FAIRCHEM
# Skipping: PGIL
# Skipping: ELECON
# Skipping: TULSI
# Skipping: UBL
# Skipping: INTENTECH
# Skipping: RAMKY
# Skipping: PAISALO
# Skipping: TATACHEM
# Skipping: EDL
# Skipping: CAPTRUST
# Skipping: RHFL
# Skipping: BRITANNIA
# Skipping: LICNETFGSC
# Skipping: RCOM
# Skipping: AYMSYNTEX
# Skipping: BLISSGVS
# Skipping: CPSEETF
# Skipping: DICIND
# Skipping: VIKASECO
# Skipping: ZENITHBIR
# Skipping: BARTRONICS
# Skipping: INEOSSTYRO
# Skipping: TORNTPOWER
# Skipping: GOACARBON
# Skipping: BAJFINANCE
# Skipping: TVSMOTOR
# Skipping: BHARATFORG
# Skipping: INDOSOLAR
# JETFREIGHT 'Close'
# Skipping: ASTRAZEN
# Skipping: TIRUMALCHM
# GUJRAFFIA 'Close'
# Skipping: BAJAJ-AUTO
# Skipping: SBIN
# Skipping: RBLBANK
# Skipping: TCPLPACK
# Skipping: SADBHIN
# Skipping: HIMATSEIDE
# Skipping: BSLNIFTY
# Skipping: SCI
# Skipping: NILKAMAL
# Skipping: FRETAIL
# Skipping: MAHINDCIE
# Skipping: MANAKALUCO
# Skipping: LIBERTSHOE
# Skipping: GALLISPAT
# Skipping: WILLAMAGOR
# Skipping: RBL
# Skipping: GARWALLROP
# Skipping: GICRE
# Skipping: GOENKA
# Skipping: PEL
# Skipping: UNITEDBNK
# Skipping: ESSDEE
# Skipping: EROSMEDIA
# Skipping: HAVELLS
# Skipping: REMSONSIND
# Skipping: EIHOTEL
# Skipping: HIL
# AVG 'Close'
# Skipping: ORIENTPPR
# Skipping: OSWALAGRO
# Skipping: AMTEKAUTO
# MMP 'Close'
# Skipping: AIAENG
# Skipping: PATINTLOG
# RMDRIP 'Close'
# Skipping: SIL
# Skipping: PHILIPCARB
# Skipping: KSBPUMPS
# Skipping: FSL
# Skipping: ALLCARGO
# Skipping: MEP
# Skipping: INDIGO
# SHRENIK 'Close'
# Skipping: DBCORP
# Skipping: SHAKTIPUMP
# HITECH 'Close'
# Skipping: UTINIFTETF
# RELIABLE 'Close'
# Skipping: SUPREMEINF
# Skipping: SHEMAROO
# Skipping: FMNL
# Skipping: OMAXAUTO
# Skipping: MANINDS
# Skipping: ERIS
# Skipping: GLOBUSSPR
# Skipping: SMARTLINK
# Skipping: UCALFUEL
# Skipping: GAMMNINFRA
# Skipping: SFL
# Skipping: CROMPTON
# Skipping: EBANK
# Skipping: NIFTYBEES
# Skipping: PAGEIND
# Skipping: KRIDHANINF
# Skipping: PRAENG
# Skipping: TEXMOPIPES
# Skipping: WHEELS
# Skipping: RML
# Skipping: SUMEETINDS
# Skipping: VIVIDHA
# Skipping: APCL
# Skipping: TNTELE
# Skipping: NITINFIRE
# Skipping: PANAMAPET
# Skipping: GMDCLTD
# Skipping: ECLERX
# Skipping: NETWORK18
# Skipping: KEYCORPSER
# Skipping: SANOFI
# UNIINFO 'Close'
# Skipping: INDIANB
# Skipping: KECL
# Skipping: SEPOWER
# Skipping: DHAMPURSUG
# Skipping: BINDALAGRO
# Skipping: SORILINFRA
# Skipping: NMDC
# Skipping: BAJAJCORP
# Skipping: KESARENT
# Skipping: NTL
# Skipping: ALCHEM
# SGBNOV24 'Close'
# Skipping: SJVN
# Skipping: MCDHOLDING
# Skipping: SESHAPAPER
# Skipping: BANSWRAS
# Skipping: GOLDBEES
# Skipping: RAYMOND
# Skipping: MRPL
# Skipping: VIDEOIND
# Skipping: KABRAEXTRU
# Skipping: CARERATING
# PIGL 'Close'
# Skipping: PDPL
# Skipping: MARICO
# SINTERCOM 'Close'
# Skipping: SHK
# Skipping: HDFCBANK
# Skipping: ANGIND
# Skipping: CHAMBLFERT
# Skipping: JISLJALEQS
# Skipping: DIGJAMLTD
# Skipping: REPCOHOME
# Skipping: JAYNECOIND
# Skipping: BIRLACORPN
# Skipping: MCLEODRUSS
# Skipping: ADANIPORTS
# Skipping: ULTRACEMCO
# Skipping: ECEIND
# Skipping: VIJAYABANK
# Skipping: GULFPETRO
# Skipping: TARAPUR
# Skipping: APLLTD
# Skipping: GLAXO
# Skipping: TATAGLOBAL
# Skipping: ANANTRAJ
# Skipping: ANDHRACEMT
# Skipping: SICAL
# Skipping: PVP
# Skipping: ASAL
# Skipping: AARVEEDEN
# Skipping: BERGEPAINT
# Skipping: JYOTISTRUC
# Skipping: ARROWTEX
# Skipping: MRF
# SONISOYA 'Close'
# Skipping: ADANITRANS
# Skipping: NOCIL
# Skipping: RATNAMANI
# Skipping: PRAXIS
# Skipping: RKFORGE
# Skipping: NIACL
# Skipping: EDUCOMP
# Skipping: GREENFIRE
# Skipping: MATRIMONY
# Skipping: ALOKTEXT
# Skipping: NKIND
# Skipping: ANDHRABANK
# Skipping: SAMBHAAV
# Skipping: IITL
# Skipping: BURNPUR
# Skipping: TAINWALCHM
# Skipping: BILENERGY
# KAPSTON 'Close'
# Skipping: SUVEN
# Skipping: SIYSIL
# Skipping: LITL
# L&TINFRA 'Close'
# HUSYSLTD 'Close'
# Skipping: LSIL
# Skipping: REFEX
# Skipping: AXISNIFTY
# Skipping: GPTINFRA
# RELIFIN 'Close'
# Skipping: HMVL
# Skipping: GTPL
# Skipping: ESCORTS
# Skipping: HTMEDIA
# Skipping: VSSL
# Skipping: ARCHIES
# Skipping: FDC
# Skipping: A2ZINFRA
# Skipping: HOTELEELA
# Skipping: NEXTMEDIA
# Skipping: NIITTECH
# Skipping: KOTAKNIFTY
# Skipping: DEN
# Skipping: SPENTEX
# CHEMFAB 'Close'
# Skipping: PNCINFRA
# Skipping: TIPSINDLTD
# Skipping: AKZOINDIA
# Skipping: ABMINTLTD
# Skipping: TWL
# Skipping: STAMPEDE
# Skipping: AUTOIND
# Skipping: APARINDS
# Skipping: DWARKESH
# Skipping: RNAM
# Skipping: CEATLTD
# Skipping: RJL
# Skipping: IDEA
# Skipping: MANGTIMBER
# Skipping: SCHNEIDER
# Skipping: SANGHVIMOV
# Skipping: KHADIM
# Skipping: SPMLINFRA
# Skipping: MBLINFRA
# Skipping: TEXINFRA
# Skipping: DENORA
# Skipping: ORIENTABRA
# MIDHANI index 1 is out of bounds for axis 1 with size 1
# Skipping: ICRA
# Skipping: ANSALHSG
# Skipping: MAXINDIA
# Skipping: FACT
# SECURCRED 'Close'
# Skipping: RUPA
# Skipping: SHREECEM
# Skipping: LYPSAGEMS
# Skipping: URJA
# Skipping: AGARIND
# Skipping: MAHABANK
# Skipping: INDORAMA
# Skipping: IGL
# Skipping: KOTAKNV20
# Skipping: SHILPAMED
# Skipping: JPOLYINVST
# Skipping: MAGNUM
# Skipping: NCC
# Skipping: GTLINFRA
# Skipping: SALORAINTL
# Skipping: METALFORGE
# Skipping: BANARBEADS
# IREDA 'Close'
# Skipping: UVSL
# Skipping: VENKEYS
# Skipping: ZYLOG
# Skipping: KERNEX
# Skipping: IGPL
# Skipping: KOTAKBKETF
# Skipping: PNBHOUSING
# Skipping: PRABHAT
# Skipping: BAGFILMS
# Skipping: COROMANDEL
# Skipping: NIPPOBATRY
# Skipping: MADHUCON
# Skipping: DLINKINDIA
# Skipping: SOMATEX
# Skipping: HINDUNILVR
# Skipping: VARDHACRLC
# Skipping: BANKINDIA
# GIRIRAJ 'Close'
# Skipping: BHARATWIRE
# Skipping: ALKYLAMINE
# AKASH 'Close'
# AGROPHOS 'Close'
# Skipping: AJMERA
# Skipping: M50
# Skipping: NITCO
# Skipping: ADVENZYMES
# Skipping: FIRSTWIN
# Skipping: PRAKASH
# Skipping: HUBTOWN
# Skipping: SUJANAUNI
# Skipping: BASML
# Skipping: SUPREMEIND
# Skipping: THERMAX
# Skipping: IPAPPM
# Skipping: PROVOGE
# Skipping: MANINFRA
# Skipping: CNOVAPETRO
# Skipping: MAXVIL
# Skipping: GODREJCP
# Skipping: JMFINANCIL
# Skipping: EXCELCROP
# Skipping: JUBLINDS
# Skipping: ACC
# Skipping: AARTIIND
# Skipping: SUDARSCHEM
# Skipping: JUBILANT
# Skipping: TARAJEWELS
# IIFLFIN 'Close'
# ERFLNCDI 'Close'
# Skipping: GABRIEL
# Skipping: KOPRAN
# Skipping: MARALOVER
# ARTNIRMAN 'Close'
# Skipping: PATELENG
# Skipping: CESC
# Skipping: NTPC
# Skipping: CELESTIAL
# Skipping: PFS
# Skipping: AJANTPHARM
# Skipping: DYNAMATECH
# Skipping: VSTIND
# Skipping: FEL
# Skipping: SHARONBIO
# Skipping: IBVENTURES
# Skipping: NDTV
# Skipping: KILITCH
# H1190M36RG 'Close'
# Skipping: ARVIND
# LEXUS 'Close'
# Skipping: ZENITHEXPO
# Skipping: ELECTHERM
# Skipping: POCHIRAJU
# Skipping: BBTC
# Skipping: TCI
# Skipping: STARPAPER
# Skipping: QUICKHEAL
# PANSARI 'Close'
# Skipping: VICEROY
# Skipping: ONELIFECAP
# Skipping: GODREJAGRO
# Skipping: HISARMETAL
# Skipping: TIJARIA
# Skipping: BRFL
# Skipping: LGBFORGE
# Skipping: NBVENTURES
# Skipping: DECCANCE
# MITTAL 'Close'
# Skipping: WINDMACHIN
# Skipping: ARMANFIN
# Skipping: ORISSAMINE
# Skipping: ARCOTECH
# Skipping: ALBK
# Skipping: BSELINFRA
# Skipping: MERCK
# Skipping: BIL
# Skipping: WONDERLA
# Skipping: STAR
# Skipping: GHCL
# Skipping: SURYAROSNI
# Skipping: ZODJRDMKJ
# Skipping: COUNCODOS
# Skipping: SWANENERGY
# Skipping: WSTCSTPAPR
# Skipping: NAGREEKEXP
# Skipping: TCIDEVELOP
# Skipping: PARAGMILK
# Skipping: KCPSUGIND
# Skipping: RICOAUTO
# MDL 'Close'
# Skipping: TBZ
# Skipping: ASHOKLEY
# LIBAS 'Close'
# Skipping: TRF
# MCL 'Close'
# Skipping: ELAND
# Skipping: PREMIER
# Skipping: PKTEA
# Skipping: SHALPAINTS
# PULZ 'Close'
# Skipping: IZMO
# Skipping: CEREBRAINT
# Skipping: ICICIPRULI
# Skipping: BSLGOLDETF
# NHBTF2023 'Close'
# Skipping: DCAL
# Skipping: HONDAPOWER
# Skipping: GTNTEX
# Skipping: PIIND
# Skipping: LASA
# DPABHUSHAN 'Close'
# Skipping: GOLDTECH
# Skipping: SOTL
# Skipping: TTKPRESTIG
# Skipping: KSL
# Skipping: SHREERAMA
# Skipping: KOLTEPATIL
# Skipping: ALPSINDUS
# Skipping: NAUKRI
# Skipping: OPTOCIRCUI
# Skipping: SADBHAV
# Skipping: RCF
# Skipping: WELSPUNIND
# Skipping: BRIGADE
# Skipping: ANIKINDS
# Skipping: ASIANTILES
# Skipping: VISHNU
# Skipping: CCHHL
# Skipping: TATASTEEL
# Skipping: GSFC
# Skipping: ANTGRAPHIC
# Skipping: TATAELXSI
# Skipping: IDBI
# Skipping: DBL
# Skipping: APOLSINHOT
# Skipping: NUCLEUS
# Skipping: CADILAHC
# Skipping: SOLARINDS
# Skipping: INDSWFTLTD
# Skipping: SNOWMAN
# Skipping: TDPOWERSYS
# Skipping: CASTROLIND
# Skipping: SUPRAJIT
# MPTODAY 'Close'
# Skipping: AHLUCONT
# Skipping: GENUSPOWER
# Skipping: HINDDORROL
# ICICISENSX 'Close'
# Skipping: KSK
# Skipping: EON
# Skipping: VISASTEEL
# Skipping: 3MINDIA
# Skipping: HSIL
# Skipping: RSYSTEMS
# Skipping: CONCOR
# Skipping: NEWGEN
# FOCUS 'Close'
# Skipping: MURUDCERA
# AAKASH 'Close'
# Skipping: SUMMITSEC
# Skipping: APEX
# Skipping: INFRATEL
# ICEMAKE 'Close'
# Skipping: FCSSOFT
# Skipping: RAMCOIND
# Skipping: PLASTIBLEN
# Skipping: IVP
# Skipping: HINDCOPPER
# Skipping: HINDUJAVEN
# Skipping: GOODLUCK
# Skipping: VIJSHAN
# SANGINITA 'Close'
# Skipping: RMCL
# Skipping: SUBEX
# Skipping: CINEVISTA
# Skipping: INOXWIND
# Skipping: KSERASERA
# Skipping: HEROMOTOCO
# Skipping: MPHASIS
# Skipping: BHEL
# Skipping: RELCONS
# Skipping: GENUSPAPER
# Skipping: SHREEPUSHK
# Skipping: GANESHHOUC
# Skipping: SBILIFE
# Skipping: BEPL
# Skipping: ICICIBANK
# Skipping: MMFL
# Skipping: SMSPHARMA
# Skipping: RAIN
# Skipping: PENINLAND
# Skipping: SPLIL
# Skipping: INGERRAND
# Skipping: ATLANTA
# Skipping: VBL
# Skipping: CONTROLPR
# Skipping: TRIVENI
# Skipping: CYIENT
# Skipping: BIRLAMONEY
# Skipping: GOKEX
# Skipping: ADLABS
# Skipping: ADANIPOWER
# Skipping: ORIENTCEM
# Skipping: SUPERHOUSE
# SGBSEP24 'Close'
# Skipping: SITINET
# Skipping: DIVISLAB
# Skipping: PSB
# AISL 'Close'
# Skipping: DATAMATICS
# Skipping: CLEDUCATE
# Skipping: SMSLIFE
# Skipping: GEOJITFSL
# Skipping: TCIFINANCE
# Skipping: GMRINFRA
# Skipping: CANTABIL
# Skipping: LOKESHMACH
# Skipping: LAMBODHARA
# Skipping: PENIND
# Skipping: PRESTIGE
# GICL 'Close'
# Skipping: FLFL
# SETFNIFBK Found array with 0 sample(s) (shape=(0, 10)) while a minimum of 1 is required.
# Skipping: MAHASTEEL
# Skipping: JINDALPOLY
# Skipping: IBULHSGFIN
# Skipping: ALMONDZ
# Skipping: ARIHANTSUP
# Skipping: SUNFLAG
# URAVI 'Close'
# Skipping: ONMOBILE
# Skipping: KARURVYSYA
# Skipping: MMTC
# Skipping: CIPLA
# Skipping: OBEROIRLTY
# Skipping: WHIRLPOOL
# Skipping: GILLANDERS
# Skipping: NFL
# Skipping: SEQUENT
# Skipping: TATACOMM
# Skipping: EMAMILTD
# Skipping: KOHINOOR
# Skipping: NEULANDLAB
# Skipping: JISLDVREQS
# Skipping: GOLDIAM
# Skipping: IVRCLINFRA
# Skipping: ENIL
# Skipping: EIHAHOTELS
# Skipping: 63MOONS
# Skipping: SAIL
# Skipping: SUNILHITEC
# Skipping: IBREALEST
# Skipping: FINPIPE
# GANGESSECU 'Close'
# Skipping: EQUITAS
# Skipping: ATLASCYCLE
# Skipping: ORCHIDPHAR
# Skipping: CARBORUNIV
# Skipping: VESUVIUS
# Skipping: SPICEMOBI
# Skipping: VGUARD
# Skipping: BAJAJHLDNG
# Skipping: ASAHIINDIA
# Skipping: MERCATOR
# Skipping: ALPA
# Skipping: WEIZFOREX
# LICNETFN50 index 1 is out of bounds for axis 1 with size 1
# Skipping: ICIL
# Skipping: COFFEEDAY
# Skipping: LTI
# Skipping: KTKBANK
# Skipping: JAYBARMARU
# Skipping: PARABDRUGS
# Skipping: CAPACITE
# Skipping: GSPL
# Skipping: SGL
# Skipping: IL&FSENGG
# Skipping: ALEMBICLTD
# Skipping: PSUBNKBEES
# Skipping: PEARLPOLY
# Skipping: IDFNIFTYET
# Skipping: MPSLTD
# Skipping: EMKAY
# Skipping: MAZDA
# Skipping: MONSANTO
# Skipping: CENTURYTEX
# Skipping: INDOCO
# Skipping: NECCLTD
# Skipping: 8KMILES
# Skipping: THANGAMAYL
# Skipping: LAKSHMIEFL
# Skipping: SINTEX
# Skipping: JBCHEPHARM
# Skipping: SAKSOFT
# Skipping: LML
# Skipping: JYOTHYLAB
# MCDOWELL-N 'Close'
# Skipping: ZYDUSWELL
# Skipping: ANSALAPI
# Skipping: HCG
# Skipping: POLARIS
# Skipping: SRF
# Skipping: GSKCONS
# Skipping: JINDWORLD
# Skipping: APOLLOHOSP
# Skipping: SHALBY
# SETFNN50 Found array with 0 sample(s) (shape=(0, 10)) while a minimum of 1 is required.
# Skipping: BLUEDART
# Skipping: KANANIIND
# Skipping: M&MFIN
# Skipping: NBCC
# Skipping: ORIENTREF
# Skipping: TATAMOTORS
# Skipping: STCINDIA
# Skipping: 5PAISA
# Skipping: PGHH
# Skipping: FOSECOIND
# Skipping: GSS
# ICICIMCAP Found array with 0 sample(s) (shape=(0, 9)) while a minimum of 1 is required.
# SILLYMONKS 'Close'
# SRPL 'Close'
# Skipping: EUROCERA
# Skipping: INFIBEAM
# ADROITINFO Length of values does not match length of index
# Skipping: SKFINDIA
# Skipping: BUTTERFLY
# Skipping: HOTELRUGBY
# NARMADA 'Close'
# PUSHPREALM 'Close'
# Skipping: ICSA
# Skipping: ARVSMART
# Skipping: ESSARSHPNG
# Skipping: SASTASUNDR
# Skipping: ITDC
# Skipping: BGLOBAL
# Skipping: MUKANDENGG
# Skipping: N100
# Skipping: GROBTEA
# Skipping: SHANTIGEAR
# Skipping: BIRLACABLE
# Skipping: BRNL
# Skipping: FEDDERELEC
# Skipping: CALSOFT
# Skipping: ZICOM
# Skipping: VIDHIING
# Skipping: JOCIL
# Skipping: VHL
# Skipping: USHERAGRO
# Skipping: VINYLINDIA
# JNPT 'Close'
# TIRUPATI 'Close'
# Skipping: TITAN
# Skipping: BSE
# Skipping: LINCOLN
# Skipping: COLPAL
# Skipping: CUMMINSIND
# Skipping: ADANIENT
# Skipping: HIRECT
# Skipping: OCCL
# Skipping: BLS
# UNIVASTU 'Close'
# Skipping: DHANUKA
# Skipping: IVZINGOLD
# Skipping: BAFNAPHARM
# Skipping: GRPLTD
# Skipping: BOSCHLTD
# Skipping: OCL
# Skipping: CCCL
# Skipping: NAHARCAP
# Skipping: MTEDUCARE
# Skipping: NIITLTD
# Skipping: MALUPAPER
# Skipping: BALMLAWRIE
# Skipping: BPL
# Skipping: CAREERP
# Skipping: MASTEK
# Skipping: TTL
# Skipping: TATASPONGE
# Skipping: RAMCOSYS
# Skipping: IIFL
# Skipping: AVANTIFEED
# Skipping: JSLHISAR
# SUNDARMHLD index 1 is out of bounds for axis 1 with size 1
# Skipping: MANALIPETC
# Skipping: PITTILAM
# Skipping: FINCABLES
# Skipping: NITINSPIN
# Skipping: REGENCERAM
# Skipping: INDUSINDBK
# Skipping: GPIL
# Skipping: SYMPHONY
# Skipping: LFIC
# Skipping: AKSHARCHEM
# Skipping: HDIL
# Skipping: L&TFH
# Skipping: GUJALKALI
# Skipping: SYNDIBANK
# FOURTHDIM 'Close'
# Skipping: SQSBFSI
# Skipping: ORIENTBANK
# Skipping: RELCNX100
# Skipping: RIIL
# Skipping: ABBOTINDIA
# MHHL 'Close'
# Skipping: TTKHLTCARE
# Skipping: UJJIVAN
# Skipping: JBMA
# Skipping: GREENPLY
# Skipping: VTL
# Skipping: ORIENTHOT
# Skipping: VINDHYATEL
# Skipping: XPROINDIA
# Skipping: KPRMILL
# Skipping: HCLTECH
# IRFC 'Close'
# Skipping: BHARATRAS
# Skipping: LAKSHVILAS
# Skipping: 3IINFOTECH
# CMMIPL 'Close'
# Skipping: PARACABLES
# Skipping: SCHAEFFLER
# SETFNIF50 index 1 is out of bounds for axis 1 with size 1
# Skipping: POWERGRID
# Skipping: ELGIEQUIP
# Skipping: JKLAKSHMI
# Skipping: SUNTECK
# VERTOZ 'Close'
# Skipping: PRESSMN
# Skipping: SKIPPER
# Skipping: NAHARSPING
# Skipping: ROHLTD
# Skipping: PAPERPROD
# Skipping: ZENSARTECH
# UTIFEFRGR4 'Close'
# Skipping: PRECAM
# Skipping: V2RETAIL
# Skipping: RAJSREESUG
# Skipping: PDSMFL
# Skipping: TIINDIA
# Skipping: ZUARIGLOB
# Skipping: HCC
# Skipping: BPCL
# Skipping: KHANDSE
# Skipping: J&KBANK
# Skipping: AUROPHARMA
# Skipping: HINDOILEXP
# LIQUIDETF Found array with 0 sample(s) (shape=(0, 12)) while a minimum of 1 is required.
# Skipping: MOTILALOFS
# Skipping: EASUNREYRL
# Skipping: CASTEXTECH
# Skipping: SHIRPUR-G
# Skipping: UNITECH
# Skipping: SUNDARMFIN
# Skipping: JSWENERGY
# Skipping: BFUTILITIE
# Skipping: UJAAS
# Skipping: DISHTV
# Skipping: GULFOILLUB
# Skipping: GVKPIL
# Skipping: CANBK
# Skipping: SPAL
# Skipping: REVATHI
# EHFLNCD 'Close'
# Skipping: TRIDENT
# Skipping: RAJOIL
# Skipping: RELCAPITAL
# Skipping: SUPPETRO
# PRSMJOHNSN 'Close'
# Skipping: ORIENTALTL
# Skipping: SIEMENS
# Skipping: PIRPHYTO
# Skipping: WELCORP
# Skipping: MAHSEAMLES
# Skipping: CERA
# Skipping: BROOKS
# Skipping: CONSOFINVT
# Skipping: LUMAXTECH
# Skipping: RAMSARUP
# Skipping: KOTARISUG
# Skipping: ALANKIT
# Skipping: BALRAMCHIN
# Skipping: ESL
# Skipping: SANDHAR
# Skipping: HINDNATGLS
# Skipping: SRHHYPOLTD
# MACPOWER 'Close'
# ICICILOVOL Found array with 0 sample(s) (shape=(0, 9)) while a minimum of 1 is required.
# NANDANI 'Close'
# BHAGYANGR 'Close'
# Skipping: AMBER
# Skipping: ROLLT
# Skipping: HNGSNGBEES
# Skipping: KIOCL
# Skipping: TTML
# Skipping: GODFRYPHLP
# Skipping: INDNIPPON
# Skipping: SHIVAMAUTO
# Skipping: PENPEBS
# Skipping: UTISENSETF
# Skipping: MUNJALSHOW
# Skipping: IOC
# Skipping: HEXATRADEX
# GMMPFAUDLR 'Close'
# Skipping: QGOLDHALF
# Skipping: DAMODARIND
# Skipping: SHRIRAMCIT
# Skipping: REPRO
# Skipping: JPASSOCIAT
# Skipping: HIKAL
# Skipping: SERVALL
# Skipping: ASHIMASYN
# Skipping: VMART
# Skipping: DHFL
# Skipping: GAEL
# Skipping: GAYAPROJ
# Skipping: NILAINFRA
# Skipping: BHARATFIN
# Skipping: APTECHT
# Skipping: SOMANYCERA
# Skipping: HEXAWARE
# Skipping: AIFL
# Skipping: EIMCOELECO
# Skipping: GREENLAM
# Skipping: ABFRL
# Skipping: SILINV
# Skipping: PNB
# Skipping: SALZERELEC
# Skipping: EIDPARRY
# Skipping: MADHAV
# Skipping: NESTLEIND
# Skipping: LAKPRE
# Skipping: AMDIND
# Skipping: XCHANGING
# Skipping: RELIGARE
# Skipping: BOMDYEING
# Skipping: ALLSEC
# Skipping: SURYALAXMI
# Skipping: RAJESHEXPO
# Skipping: RTNINFRA
# Skipping: MANAKSTEEL
# Skipping: MOTHERSUMI
# Skipping: BLBLIMITED
# Skipping: WIPL
# Skipping: PETRONET
# Skipping: NIFTYEES
# Skipping: AGLSL
# SHANTI 'Close'
# AIRAN 'Close'
# Skipping: TASTYBITE
# Skipping: SANCO
# Skipping: CGCL
# Skipping: LINDEINDIA
# Skipping: BLUECOAST
# Skipping: NDGL
# Skipping: PVR
# Skipping: UGARSUGAR
# Skipping: IDFC
# Skipping: MOSERBAER
# Skipping: VINATIORGA
# Skipping: TVTODAY
# Skipping: JSWSTEEL
# VASA 'Close'
# Skipping: DFMFOODS
# Skipping: ABAN
# Skipping: JUNIORBEES
# Skipping: SRIPIPES
# Skipping: INDLMETER
# Skipping: INTELLECT
# Skipping: TIMETECHNO
# Skipping: BAJAJFINSV
# Skipping: SALONA
# Skipping: CDSL
# Skipping: MANAKSIA
# Skipping: UNIENTER
# Skipping: CANFINHOME
# Skipping: KAJARIACER
# Skipping: GOLDSHARE
# Skipping: AUBANK
# Skipping: GOLDENTOBC
# CADSYS 'Close'
# Skipping: TECHIN
# Skipping: KAMDHENU
# Skipping: AMBIKCO
# Skipping: JVLAGRO
# Skipping: UTTAMSUGAR
# Skipping: TFL
# Skipping: KAUSHALYA
# Skipping: IVC
# Skipping: CUPID
# Skipping: MINDTREE
# Skipping: LUMAXIND
# Skipping: BINANIIND
# Skipping: FCONSUMER
# Skipping: INDIACEM
# Skipping: NELCAST
# Skipping: BALKRISHNA
# Skipping: HATSUN
# Skipping: CYBERMEDIA
# Skipping: PURVA
# Skipping: ENDURANCE
# Skipping: LEEL
# Skipping: THIRUSUGAR
# Skipping: GIPCL
# SGBNOV25VI 'Close'
# Skipping: DENABANK
# Skipping: MUNJALAU
# Skipping: NLCINDIA
# TCFSL 'Close'
# Skipping: JHS
# Skipping: JMTAUTOLTD
# Skipping: TIL
# Skipping: JMCPROJECT
# SGBOCT25 'Close'
# SKSTEXTILE 'Close'
# Skipping: SALASAR
# Skipping: BHANDARI
# Skipping: SANGAMIND
# Skipping: DIXON
# Skipping: WABCOINDIA
# Skipping: ADFFOODS
# Skipping: IFBIND
# Skipping: LIQUIDBEES
# Skipping: BGRENERGY
# Skipping: SHANKARA
# Skipping: PBAINFRA
# HAVISHA Found array with 0 sample(s) (shape=(0, 10)) while a minimum of 1 is required.
# Skipping: UMANGDAIRY
# Skipping: BVCL
# Skipping: NIBL
# Skipping: KHAITANLTD
# Skipping: SASKEN
# Skipping: RAJRAYON
# Skipping: HBLPOWER
# Skipping: CUBEXTUB
# Skipping: UFLEX
# Skipping: AXISBANK
# Skipping: BHAGERIA
# Skipping: SHYAMTEL
# Skipping: BODALCHEM
# Skipping: ZANDUREALT
# Skipping: MIRCELECTR
# Skipping: CORALFINAC
# Skipping: HCL-INSYS
# Skipping: NUTEK
# Skipping: WIPRO
# Skipping: FILATEX
# Skipping: OIL
# Skipping: SUPERSPIN
# Skipping: ESTER
# Skipping: VSTTILLERS
# Skipping: PSPPROJECT
# SARVESHWAR 'Close'
# Skipping: NHPC
# Skipping: THYROCARE
